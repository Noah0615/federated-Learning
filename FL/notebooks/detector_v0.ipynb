# %% [markdown]
# # Detector v0
# Load one run's `rounds.parquet`, inspect `cos_u_delta` and join it with Prometheus exports offline.

# %%
from pathlib import Path
import pandas as pd

runs = sorted(Path('../results').glob('*/rounds.parquet'))
df = pd.read_parquet(runs[-1]) if runs else pd.DataFrame()
df.head()
